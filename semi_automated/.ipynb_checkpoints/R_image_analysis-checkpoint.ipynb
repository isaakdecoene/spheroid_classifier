# %% [markdown]
# # Generate some output in R

# %% [markdown]
# The idea is to call this script from the python notebook for each image separately as part of the pipeline. It will create one .csv per image and some basic quality control visualisations.
#
# It should also be possible to run this directly from the python notebook.
# https://stackoverflow.com/questions/34745423/is-there-a-way-to-do-jupyter-cell-magic-with-r

# %%
# image_name <- "STELLA_sA400_fullyauto_Merge_50-20_C04_D7"
# image_name <- "STELLA_sA800_fullyauto_Merge_100-20_C01_D7"
# image_name <- "STELLA_sA400_fullyauto_Merge_50-20_D06_D7"
# image_name <- "STELLA_sA800_fullyauto_Merge_100-20_C06_D7"

# %% [markdown]
# ## Define image to be processed

# %%
results_folder <- 'stella/output/images/STELLA_sA400_semiauto_Merge_50-10_A06_D14'
# Out:
# [1] "STELLA_sA400_semiauto_Merge_50-10_A06_D14"

# %%
image_name <- basename(results_folder)
image_name

# %% [markdown]
# ## Dependencies

# %%
require("tidyr")
require("dplyr")
require("stringr")
require("ggplot2")
require("ggpubr")
require("sp") # to define spatial polygons in R
require("psych") # creates very easy summary data using the describe() function
# require("raster") # To save a shapefile 
getwd()
# Out:
# [1] "/home/host_home/20220513_spheroid_docker"

# %% [markdown]
# ## Data

# %% [markdown]
# ### Spheroids

# %%
spheroids_file <- paste0(results_folder,"/cellprofiler/cp_output_spheroids_filtered.csv")
spheroids <- read.csv(spheroids_file)
# spheroids <- read.csv('stella/input/STELLA_sA400_fullyauto_Merge_50-20_C04_D7/cellprofiler/cp_output_spheroids_filtered.csv')

# %%
pxl_per_um <- 1030/(20*400) # Measured manually
# pxl_per_um
um_per_pxl <- 1/pxl_per_um
um_per_pxl
# Out:
# [1] 7.76699

# %%
df <- spheroids 
metadata <- cbind(df[,c(1,2,3,6)], as.data.frame(str_split_fixed(df$FileName_original, "_", 7))) %>%
    setNames(., c("ID","image_id","type","FileName_original","Experiment", "Platform", "Handling", "Merge", "asp_disp", "Well", "Day")) %>%
    select(-Merge, -type)%>%
    separate(col = asp_disp, into = c("Aspiration", "Dispension"), sep = "-", remove = TRUE) %>%
    mutate_all(~gsub(".tif", "", .)) %>%
    mutate(across(where(is.character), as.factor))%>%
    mutate(ID = 1:length(df[,1]))%>%
    mutate(ID = as.numeric(ID))
# glimpse(metadata)

# %%
names(df)[2] <- 'ID'
df <- full_join(metadata,df, by = "ID")
# glimpse(df)
# View(df)

# %% [markdown]
# ### Grid

# %%
grid_file <- paste0(results_folder,"/",image_name,"_grid.csv")
grid <- read.csv(grid_file)

# %% [markdown]
# ## Define polygon object

# %% [markdown]
# Determine a set of coordinates for the vertices. Note that the first and last vertex need to be the same to 'close' the polygon.
#
# https://mhallwor.github.io/_pages/basics_SpatialPolygons

# %%
polist <- list()

for (i in 1:length(grid[,1])) {
    name <- as.character(i)
    square <- as.numeric(grid[i,])
    x_coords <- square[c(5,7,9,11,5)]
    y_coords <- square[c(6,8,10,12,6)]
    poly <- Polygon(cbind(x_coords,y_coords)) # one polygon is created 
    polyclass <- Polygons(list(poly), ID = name) # Give object class 'polygon'
    polist <- c(polist,polyclass)
}

# Turn the individual polygons in a list of spatial polygons
all_polygons <- SpatialPolygons(polist)

# %%
locations <- df %>% select(AreaShape_Center_X,AreaShape_Center_Y) %>% SpatialPoints
# glimpse(locations)

# %% [markdown]
# ### Save the polygons as a shapefile

# %%
# require(raster)
# shapefile(x = all_polygons, file = "'stella/output/images/STELLA_sA400_fullyauto_Merge_50-20_C04_D7/polygons_shapefile.shp")

# %% [markdown]
# ## Overlay points and polygons
#
# there are 2 ways: via fs package or via sp package. The sf seems easier but i cannot get it installed... https://r-spatial.github.io/sf/
#
# So we use the 'sp' package again
# https://mhallwor.github.io/_pages/basics_SpatialPolygons
# https://gis.stackexchange.com/questions/63793/how-to-overlay-a-polygon-over-spatialpointsdataframe-and-preserving-the-spdf-dat

# %%
# Create vector with the polygon each spheroid is a part of. 
overlap <- over(locations , all_polygons , fn = NULL)
# make this into a dataframe
df_overlap <- data.frame("spheroid" = 1:length(locations), "microwell" = overlap)
df_overlap$colored_spheroids <- ifelse(is.na(df_overlap$microwell), 'red', 'green')
# Add a column to spheroids df to specify in which detectable well it is located
df$uwell <- df_overlap$microwell
# glimpse(df_overlap)

# %% [markdown]
# ### Plot all microwells

# %%
polys_df <- data.frame('nr' = c(1:length(all_polygons)))
non_empty_uwells <- df_overlap %>% select(microwell) %>% drop_na()

polys_df$with_spheroid <- 0
polys_df$with_spheroid[unlist(non_empty_uwells)] <- 1
polys_df$color <- ifelse(polys_df$with_spheroid == 1, 'green', 'red')
# glimpse(polys_df)

# %%
output_png <- paste0("stella/output/images/",image_name,"/",image_name,"_grid.png")

png(file=output_png,width=1000, height=1000)
plot(all_polygons, col = polys_df$color)
points(locations, pch = 20, cex = 1)
dev.off()
# Out:
# png
#   2

# %%
output_png <- paste0("stella/output/images/",image_name,"/",image_name,"_only_grid.png")

png(file=output_png,width=1000, height=1000)
plot(all_polygons)
dev.off()
# Out:
# png
#   2

# %% [markdown]
# ### Calculate percentage of microwells containing a spheroid

# %%
percentage <- 100*sum(polys_df$with_spheroid)/length(polys_df$nr)
defects <- 100 - percentage
print(paste("From a total of ", length(polys_df$nr), "microwells, ", percentage, "% contains a spheroid, and ", defects, "% are empty."))
# Out:
# [1] "From a total of  475 microwells,  72.2105263157895 % contains a spheroid, and  27.7894736842105 % are empty."

# %% [markdown]
# ## Make some basic overview plots

# %%
# Area density
df <- df %>% mutate(AreaShape_Area = AreaShape_Area*um_per_pxl*um_per_pxl)
p <- ggplot(df, aes(AreaShape_Area, fill = Platform, group = Platform)) + 
        geom_density(alpha = 0.3)+
        # geom_vline(data=mu, aes(xintercept=grp.mean, color=Platform),linetype="dashed")+
        labs(x = "Area (µm²)", y = "Density", title = "Area distribution")+
        theme_bw()+
        theme(plot.title = element_text(hjust = 0.5), 
        text = element_text(size = 20),
        strip.text = element_text(size = 12), 
        axis.text = element_text(size = 12, color = "black"),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_blank())
p

output_png <- paste0("stella/output/images/",image_name,"/",image_name,"_Density_Area.png")
ggsave(filename = output_png, plot = p, dpi = 300, width = 8, height = 8)
# Out:
# plot without title

# %%
# Diameter density
df <- df %>% mutate(AreaShape_EquivalentDiameter = AreaShape_EquivalentDiameter*um_per_pxl)
p <- ggplot(df, aes(AreaShape_EquivalentDiameter, fill = Platform, group = Platform)) + 
        geom_density(alpha = 0.3)+
        # geom_vline(data=mu, aes(xintercept=grp.mean, color=Platform),linetype="dashed")+
        labs(x = "Diameter (µm)", y = "Density", title = "Diameter distribution")+
        theme_bw()+
        theme(plot.title = element_text(hjust = 0.5), 
        text = element_text(size = 20),
        strip.text = element_text(size = 12), 
        axis.text = element_text(size = 12, color = "black"),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_blank())
p

output_png <- paste0("stella/output/images/",image_name,"/",image_name,"_Density_Diameter.png")
ggsave(filename = output_png, plot = p, dpi = 300, width = 8, height = 8)
# Out:
# plot without title

# %% [markdown]
# # Projected volume

# %%
df <- df %>% mutate("Projected_volume_mm3" = 10^-9*(4/3*pi*(AreaShape_EquivalentDiameter/2)^3))

p <- ggplot(df, aes(Projected_volume_mm3, fill = Platform, group = Platform)) + 
        geom_density(alpha = 0.3)+
        # geom_vline(data=mu, aes(xintercept=grp.mean, color=Platform),linetype="dashed")+
        labs(x = "Projected volume (mm³)", y = "Density", title = "Volume distribution")+
        theme_bw()+
        theme(plot.title = element_text(hjust = 0.5), 
        text = element_text(size = 20),
        strip.text = element_text(size = 12), 
        axis.text = element_text(size = 12, color = "black"),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_blank())
p

output_png <- paste0("stella/output/images/",image_name,"/",image_name,"_Density_Volume.png")
ggsave(filename = output_png, plot = p, dpi = 300, width = 8, height = 8)
# Out:
# plot without title

# %% [markdown]
# # Save dataset

# %% [markdown]
# ## Save the full dataset

# %%
# Add grid detection results to df
df <- df %>% mutate("microwells" = length(polys_df$nr),
                    "spheroids" = length(df$Number_Object_Number),
                    "inwell_perc" = percentage,
                    "outwell_perc" = defects)

output_csv <- paste0("stella/output/images/",image_name,"/",image_name,"_output_data.csv")
write.csv(df,output_csv)
glimpse(df)
# Out:
# Rows: 486
# Columns: 136
# $ ID                                                       <dbl> 1, 2, 3, 4, 5…
# $ image_id                                                 <fct> 1, 2, 3, 4, 5…
# $ FileName_original.x                                      <fct> /home/host_ho…
# $ Experiment                                               <fct> STELLA, STELL…
# $ Platform                                                 <fct> sA400, sA400,…
# $ Handling                                                 <fct> semiauto, sem…
# $ Aspiration                                               <fct> 50, 50, 50, 5…
# $ Dispension                                               <fct> 10, 10, 10, 1…
# $ Well                                                     <fct> A06, A06, A06…
# $ Day                                                      <fct> D14, D14, D14…
# $ ImageNumber                                              <int> 1, 1, 1, 1, 1…
# $ FileName_original.y                                      <chr> "STELLA_sA400…
# $ FileName_probabilities                                   <chr> "STELLA_sA400…
# $ PathName_original                                        <chr> "/home/host_h…
# $ PathName_probabilities                                   <chr> "/home/host_h…
# $ AreaShape_Area                                           <dbl> 2616.499, 409…
# $ AreaShape_BoundingBoxArea                                <int> 480, 648, 210…
# $ AreaShape_BoundingBoxMaximum_X                           <int> 83, 1358, 840…
# $ AreaShape_BoundingBoxMaximum_Y                           <int> 24, 29, 28, 3…
# $ AreaShape_BoundingBoxMinimum_X                           <int> 59, 1334, 826…
# $ AreaShape_BoundingBoxMinimum_Y                           <int> 4, 2, 13, 11,…
# $ AreaShape_Center_X                                       <dbl> 70.38951, 134…
# $ AreaShape_Center_Y                                       <dbl> 14.01873, 14.…
# $ AreaShape_Compactness                                    <dbl> 1.625061, 1.4…
# $ AreaShape_ConvexArea                                     <int> 308, 474, 139…
# $ AreaShape_Eccentricity                                   <dbl> 0.7313192, 0.…
# $ AreaShape_EquivalentDiameter                             <dbl> 57.71854, 72.…
# $ AreaShape_EulerNumber                                    <int> 1, 1, 1, 1, 1…
# $ AreaShape_Extent                                         <dbl> 0.5562500, 0.…
# $ AreaShape_FormFactor                                     <dbl> 0.6153617, 0.…
# $ AreaShape_MajorAxisLength                                <dbl> 23.64561, 29.…
# $ AreaShape_MaxFeretDiameter                               <dbl> 24.16609, 31.…
# $ AreaShape_MaximumRadius                                  <dbl> 7.071068, 8.0…
# $ AreaShape_MeanRadius                                     <dbl> 2.719202, 3.3…
# $ AreaShape_MedianRadius                                   <dbl> 2.236068, 3.0…
# $ AreaShape_MinFeretDiameter                               <dbl> 16.26346, 20.…
# $ AreaShape_MinorAxisLength                                <dbl> 16.12715, 19.…
# $ AreaShape_Orientation                                    <dbl> -67.145554, 2…
# $ AreaShape_Perimeter                                      <dbl> 73.84062, 87.…
# $ AreaShape_Solidity                                       <dbl> 0.8668831, 0.…
# $ Intensity_IntegratedIntensityEdge_orignal_rescale        <dbl> 26.41961, 48.…
# $ Intensity_IntegratedIntensity_orignal_rescale            <dbl> 104.71765, 23…
# $ Intensity_LowerQuartileIntensity_orignal_rescale         <dbl> 0.3333333, 0.…
# $ Intensity_MADIntensity_orignal_rescale                   <dbl> 0.052941173, …
# $ Intensity_MassDisplacement_orignal_rescale               <dbl> 0.692822350, …
# $ Intensity_MaxIntensityEdge_orignal_rescale               <dbl> 0.5568628, 0.…
# $ Intensity_MaxIntensity_orignal_rescale                   <dbl> 0.5568628, 0.…
# $ Intensity_MeanIntensityEdge_orignal_rescale              <dbl> 0.4331083, 0.…
# $ Intensity_MeanIntensity_orignal_rescale                  <dbl> 0.3922009, 0.…
# $ Intensity_MedianIntensity_orignal_rescale                <dbl> 0.3882353, 0.…
# $ Intensity_MinIntensityEdge_orignal_rescale               <dbl> 0.3058824, 0.…
# $ Intensity_MinIntensity_orignal_rescale                   <dbl> 0.2313726, 0.…
# $ Intensity_StdIntensityEdge_orignal_rescale               <dbl> 0.06074241, 0…
# $ Intensity_StdIntensity_orignal_rescale                   <dbl> 0.06631495, 0…
# $ Intensity_UpperQuartileIntensity_orignal_rescale         <dbl> 0.4313726, 0.…
# $ Location_CenterMassIntensity_X_orignal_rescale           <dbl> 69.84193, 134…
# $ Location_CenterMassIntensity_Y_orignal_rescale           <dbl> 14.44317, 14.…
# $ Location_CenterMassIntensity_Z_orignal_rescale           <dbl> 0, 0, 0, 0, 0…
# $ Location_Center_X                                        <dbl> 70.38951, 134…
# $ Location_Center_Y                                        <dbl> 14.01873, 14.…
# $ Location_Center_Z                                        <int> 0, 0, 0, 0, 0…
# $ Location_MaxIntensity_X_orignal_rescale                  <dbl> 61, 1336, 828…
# $ Location_MaxIntensity_Y_orignal_rescale                  <dbl> 16, 2, 15, 23…
# $ Location_MaxIntensity_Z_orignal_rescale                  <dbl> 0, 0, 0, 0, 0…
# $ Number_Object_Number                                     <int> 1, 2, 3, 4, 5…
# $ Parent_spheroids                                         <int> 1, 2, 3, 4, 7…
# $ RadialDistribution_FracAtD_orignal_rescale_1of4          <dbl> 0.02988428, 0…
# $ RadialDistribution_FracAtD_orignal_rescale_2of4          <dbl> 0.1195746, 0.…
# $ RadialDistribution_FracAtD_orignal_rescale_3of4          <dbl> 0.2998538, 0.…
# $ RadialDistribution_FracAtD_orignal_rescale_4of4          <dbl> 0.5506874, 0.…
# $ RadialDistribution_MeanFrac_orignal_rescale_1of4         <dbl> 0.7979103, 0.…
# $ RadialDistribution_MeanFrac_orignal_rescale_2of4         <dbl> 0.8401686, 0.…
# $ RadialDistribution_MeanFrac_orignal_rescale_3of4         <dbl> 0.9418937, 0.…
# $ RadialDistribution_MeanFrac_orignal_rescale_4of4         <dbl> 1.0972651, 1.…
# $ RadialDistribution_RadialCV_orignal_rescale_1of4         <dbl> 0.083332558, …
# $ RadialDistribution_RadialCV_orignal_rescale_2of4         <dbl> 0.11023130, 0…
# $ RadialDistribution_RadialCV_orignal_rescale_3of4         <dbl> 0.10638831, 0…
# $ RadialDistribution_RadialCV_orignal_rescale_4of4         <dbl> 0.112058942, …
# $ Texture_AngularSecondMoment_orignal_rescale_3_00_256     <dbl> 0.004075000, …
# $ Texture_AngularSecondMoment_orignal_rescale_3_01_256     <dbl> 0.004643408, …
# $ Texture_AngularSecondMoment_orignal_rescale_3_02_256     <dbl> 0.004132231, …
# $ Texture_AngularSecondMoment_orignal_rescale_3_03_256     <dbl> 0.003919668, …
# $ Texture_Contrast_orignal_rescale_3_00_256                <dbl> 187.10500, 12…
# $ Texture_Contrast_orignal_rescale_3_01_256                <dbl> 261.45509, 20…
# $ Texture_Contrast_orignal_rescale_3_02_256                <dbl> 154.99495, 13…
# $ Texture_Contrast_orignal_rescale_3_03_256                <dbl> 247.12632, 20…
# $ Texture_Correlation_orignal_rescale_3_00_256             <dbl> 0.63867059, 0…
# $ Texture_Correlation_orignal_rescale_3_01_256             <dbl> 0.46131064, 0…
# $ Texture_Correlation_orignal_rescale_3_02_256             <dbl> 0.72085654, 0…
# $ Texture_Correlation_orignal_rescale_3_03_256             <dbl> 0.52757578, 0…
# $ Texture_DifferenceEntropy_orignal_rescale_3_00_256       <dbl> 4.599743, 4.4…
# $ Texture_DifferenceEntropy_orignal_rescale_3_01_256       <dbl> 4.763845, 4.6…
# $ Texture_DifferenceEntropy_orignal_rescale_3_02_256       <dbl> 4.471757, 4.5…
# $ Texture_DifferenceEntropy_orignal_rescale_3_03_256       <dbl> 4.763244, 4.6…
# $ Texture_DifferenceVariance_orignal_rescale_3_00_256      <dbl> 0.0002892097,…
# $ Texture_DifferenceVariance_orignal_rescale_3_01_256      <dbl> 0.0002487313,…
# $ Texture_DifferenceVariance_orignal_rescale_3_02_256      <dbl> 0.0003285390,…
# $ Texture_DifferenceVariance_orignal_rescale_3_03_256      <dbl> 0.0002552259,…
# $ Texture_Entropy_orignal_rescale_3_00_256                 <dbl> 8.109886, 8.2…
# $ Texture_Entropy_orignal_rescale_3_01_256                 <dbl> 7.956255, 8.4…
# $ Texture_Entropy_orignal_rescale_3_02_256                 <dbl> 8.073604, 8.3…
# $ Texture_Entropy_orignal_rescale_3_03_256                 <dbl> 8.134201, 8.2…
# $ Texture_InfoMeas1_orignal_rescale_3_00_256               <dbl> -0.38769698, …
# $ Texture_InfoMeas1_orignal_rescale_3_01_256               <dbl> -0.39695471, …
# $ Texture_InfoMeas1_orignal_rescale_3_02_256               <dbl> -0.4130174, -…
# $ Texture_InfoMeas1_orignal_rescale_3_03_256               <dbl> -0.38886546, …
# $ Texture_InfoMeas2_orignal_rescale_3_00_256               <dbl> 0.9898297, 0.…
# $ Texture_InfoMeas2_orignal_rescale_3_01_256               <dbl> 0.9902315, 0.…
# $ Texture_InfoMeas2_orignal_rescale_3_02_256               <dbl> 0.9924917, 0.…
# $ Texture_InfoMeas2_orignal_rescale_3_03_256               <dbl> 0.9900953, 0.…
# $ Texture_InverseDifferenceMoment_orignal_rescale_3_00_256 <dbl> 0.08828149, 0…
# $ Texture_InverseDifferenceMoment_orignal_rescale_3_01_256 <dbl> 0.08946240, 0…
# $ Texture_InverseDifferenceMoment_orignal_rescale_3_02_256 <dbl> 0.10318052, 0…
# $ Texture_InverseDifferenceMoment_orignal_rescale_3_03_256 <dbl> 0.09227104, 0…
# $ Texture_SumAverage_orignal_rescale_3_00_256              <dbl> 193.4150, 286…
# $ Texture_SumAverage_orignal_rescale_3_01_256              <dbl> 189.8982, 284…
# $ Texture_SumAverage_orignal_rescale_3_02_256              <dbl> 195.2273, 285…
# $ Texture_SumAverage_orignal_rescale_3_03_256              <dbl> 195.9263, 283…
# $ Texture_SumEntropy_orignal_rescale_3_00_256              <dbl> 6.113853, 6.0…
# $ Texture_SumEntropy_orignal_rescale_3_01_256              <dbl> 6.140219, 5.9…
# $ Texture_SumEntropy_orignal_rescale_3_02_256              <dbl> 6.191053, 6.0…
# $ Texture_SumEntropy_orignal_rescale_3_03_256              <dbl> 6.199020, 6.0…
# $ Texture_SumVariance_orignal_rescale_3_00_256             <dbl> 848.54278, 49…
# $ Texture_SumVariance_orignal_rescale_3_01_256             <dbl> 709.25311, 39…
# $ Texture_SumVariance_orignal_rescale_3_02_256             <dbl> 955.50895, 42…
# $ Texture_SumVariance_orignal_rescale_3_03_256             <dbl> 799.07878, 39…
# $ Texture_Variance_orignal_rescale_3_00_256                <dbl> 258.91194, 15…
# $ Texture_Variance_orignal_rescale_3_01_256                <dbl> 242.677050, 1…
# $ Texture_Variance_orignal_rescale_3_02_256                <dbl> 277.625976, 1…
# $ Texture_Variance_orignal_rescale_3_03_256                <dbl> 261.55127, 15…
# $ uwell                                                    <int> NA, NA, NA, N…
# $ Projected_volume_mm3                                     <dbl> 1.006803e-04,…
# $ microwells                                               <int> 475, 475, 475…
# $ spheroids                                                <int> 486, 486, 486…
# $ inwell_perc                                              <dbl> 72.21053, 72.…
# $ outwell_perc                                             <dbl> 27.78947, 27.…

# %% [markdown]
# ## Save a summary dataset

# %%
# Create summary table
df_summary <- as.data.frame(t(describe(df[,16:length(df)])))
df_summary <- cbind(df[1:13,1:11], df_summary)
# Add metadata
metadata_cols <- c(1:11)
df_summary$Row <- substr(df_summary$Well, 1,1)
df_summary$Column <- substr(gsub("0","",df_summary$Well),2,3)
glimpse(df_summary)
# Out:
# Rows: 13
# Columns: 134
# $ ID                                                       <dbl> 1, 2, 3, 4, 5…
# $ image_id                                                 <fct> 1, 2, 3, 4, 5…
# $ FileName_original.x                                      <fct> /home/host_ho…
# $ Experiment                                               <fct> STELLA, STELL…
# $ Platform                                                 <fct> sA400, sA400,…
# $ Handling                                                 <fct> semiauto, sem…
# $ Aspiration                                               <fct> 50, 50, 50, 5…
# $ Dispension                                               <fct> 10, 10, 10, 1…
# $ Well                                                     <fct> A06, A06, A06…
# $ Day                                                      <fct> D14, D14, D14…
# $ ImageNumber                                              <int> 1, 1, 1, 1, 1…
# $ AreaShape_Area                                           <dbl> 1.000000, 486…
# $ AreaShape_BoundingBoxArea                                <dbl> 2.000000, 486…
# $ AreaShape_BoundingBoxMaximum_X                           <dbl> 3.0000000, 48…
# $ AreaShape_BoundingBoxMaximum_Y                           <dbl> 4.0000000, 48…
# $ AreaShape_BoundingBoxMinimum_X                           <dbl> 5.0000000, 48…
# $ AreaShape_BoundingBoxMinimum_Y                           <dbl> 6.000000, 486…
# $ AreaShape_Center_X                                       <dbl> 7.0000000, 48…
# $ AreaShape_Center_Y                                       <dbl> 8.0000000, 48…
# $ AreaShape_Compactness                                    <dbl> 9.000000000, …
# $ AreaShape_ConvexArea                                     <dbl> 10.000000, 48…
# $ AreaShape_Eccentricity                                   <dbl> 11.000000000,…
# $ AreaShape_EquivalentDiameter                             <dbl> 12.0000000, 4…
# $ AreaShape_EulerNumber                                    <dbl> 13, 486, 1, 0…
# $ AreaShape_Extent                                         <dbl> 14.000000000,…
# $ AreaShape_FormFactor                                     <dbl> 15.000000000,…
# $ AreaShape_MajorAxisLength                                <dbl> 16.0000000, 4…
# $ AreaShape_MaxFeretDiameter                               <dbl> 17.0000000, 4…
# $ AreaShape_MaximumRadius                                  <dbl> 18.00000000, …
# $ AreaShape_MeanRadius                                     <dbl> 1.900000e+01,…
# $ AreaShape_MedianRadius                                   <dbl> 20.00000000, …
# $ AreaShape_MinFeretDiameter                               <dbl> 21.0000000, 4…
# $ AreaShape_MinorAxisLength                                <dbl> 22.0000000, 4…
# $ AreaShape_Orientation                                    <dbl> 23.000000000,…
# $ AreaShape_Perimeter                                      <dbl> 24.0000000, 4…
# $ AreaShape_Solidity                                       <dbl> 25.000000000,…
# $ Intensity_IntegratedIntensityEdge_orignal_rescale        <dbl> 26.0000000, 4…
# $ Intensity_IntegratedIntensity_orignal_rescale            <dbl> 27.0000000, 4…
# $ Intensity_LowerQuartileIntensity_orignal_rescale         <dbl> 28.000000000,…
# $ Intensity_MADIntensity_orignal_rescale                   <dbl> 29.000000000,…
# $ Intensity_MassDisplacement_orignal_rescale               <dbl> 3.000000e+01,…
# $ Intensity_MaxIntensityEdge_orignal_rescale               <dbl> 31.000000000,…
# $ Intensity_MaxIntensity_orignal_rescale                   <dbl> 32.000000000,…
# $ Intensity_MeanIntensityEdge_orignal_rescale              <dbl> 33.000000000,…
# $ Intensity_MeanIntensity_orignal_rescale                  <dbl> 34.000000000,…
# $ Intensity_MedianIntensity_orignal_rescale                <dbl> 35.000000000,…
# $ Intensity_MinIntensityEdge_orignal_rescale               <dbl> 36.00000000, …
# $ Intensity_MinIntensity_orignal_rescale                   <dbl> 37.000000000,…
# $ Intensity_StdIntensityEdge_orignal_rescale               <dbl> 38.000000000,…
# $ Intensity_StdIntensity_orignal_rescale                   <dbl> 39.000000000,…
# $ Intensity_UpperQuartileIntensity_orignal_rescale         <dbl> 40.000000000,…
# $ Location_CenterMassIntensity_X_orignal_rescale           <dbl> 41.0000000, 4…
# $ Location_CenterMassIntensity_Y_orignal_rescale           <dbl> 42.0000000, 4…
# $ Location_CenterMassIntensity_Z_orignal_rescale           <dbl> 43, 486, 0, 0…
# $ Location_Center_X                                        <dbl> 44.0000000, 4…
# $ Location_Center_Y                                        <dbl> 45.0000000, 4…
# $ Location_Center_Z                                        <dbl> 46, 486, 0, 0…
# $ Location_MaxIntensity_X_orignal_rescale                  <dbl> 47.0000000, 4…
# $ Location_MaxIntensity_Y_orignal_rescale                  <dbl> 48.00000000, …
# $ Location_MaxIntensity_Z_orignal_rescale                  <dbl> 49, 486, 0, 0…
# $ Number_Object_Number                                     <dbl> 50.000000, 48…
# $ Parent_spheroids                                         <dbl> 51.00000000, …
# $ RadialDistribution_FracAtD_orignal_rescale_1of4          <dbl> 5.200000e+01,…
# $ RadialDistribution_FracAtD_orignal_rescale_2of4          <dbl> 5.300000e+01,…
# $ RadialDistribution_FracAtD_orignal_rescale_3of4          <dbl> 5.400000e+01,…
# $ RadialDistribution_FracAtD_orignal_rescale_4of4          <dbl> 5.500000e+01,…
# $ RadialDistribution_MeanFrac_orignal_rescale_1of4         <dbl> 56.000000000,…
# $ RadialDistribution_MeanFrac_orignal_rescale_2of4         <dbl> 5.700000e+01,…
# $ RadialDistribution_MeanFrac_orignal_rescale_3of4         <dbl> 58.000000000,…
# $ RadialDistribution_MeanFrac_orignal_rescale_4of4         <dbl> 59.000000000,…
# $ RadialDistribution_RadialCV_orignal_rescale_1of4         <dbl> 6.000000e+01,…
# $ RadialDistribution_RadialCV_orignal_rescale_2of4         <dbl> 6.100000e+01,…
# $ RadialDistribution_RadialCV_orignal_rescale_3of4         <dbl> 6.200000e+01,…
# $ RadialDistribution_RadialCV_orignal_rescale_4of4         <dbl> 6.300000e+01,…
# $ Texture_AngularSecondMoment_orignal_rescale_3_00_256     <dbl> 6.400000e+01,…
# $ Texture_AngularSecondMoment_orignal_rescale_3_01_256     <dbl> 6.500000e+01,…
# $ Texture_AngularSecondMoment_orignal_rescale_3_02_256     <dbl> 6.600000e+01,…
# $ Texture_AngularSecondMoment_orignal_rescale_3_03_256     <dbl> 6.700000e+01,…
# $ Texture_Contrast_orignal_rescale_3_00_256                <dbl> 68.0000000, 4…
# $ Texture_Contrast_orignal_rescale_3_01_256                <dbl> 69.0000000, 4…
# $ Texture_Contrast_orignal_rescale_3_02_256                <dbl> 7.000000e+01,…
# $ Texture_Contrast_orignal_rescale_3_03_256                <dbl> 71.0000000, 4…
# $ Texture_Correlation_orignal_rescale_3_00_256             <dbl> 72.00000000, …
# $ Texture_Correlation_orignal_rescale_3_01_256             <dbl> 73.000000000,…
# $ Texture_Correlation_orignal_rescale_3_02_256             <dbl> 74.000000000,…
# $ Texture_Correlation_orignal_rescale_3_03_256             <dbl> 75.000000000,…
# $ Texture_DifferenceEntropy_orignal_rescale_3_00_256       <dbl> 76.00000000, …
# $ Texture_DifferenceEntropy_orignal_rescale_3_01_256       <dbl> 77.00000000, …
# $ Texture_DifferenceEntropy_orignal_rescale_3_02_256       <dbl> 78.00000000, …
# $ Texture_DifferenceEntropy_orignal_rescale_3_03_256       <dbl> 79.00000000, …
# $ Texture_DifferenceVariance_orignal_rescale_3_00_256      <dbl> 8.000000e+01,…
# $ Texture_DifferenceVariance_orignal_rescale_3_01_256      <dbl> 8.100000e+01,…
# $ Texture_DifferenceVariance_orignal_rescale_3_02_256      <dbl> 8.200000e+01,…
# $ Texture_DifferenceVariance_orignal_rescale_3_03_256      <dbl> 8.300000e+01,…
# $ Texture_Entropy_orignal_rescale_3_00_256                 <dbl> 84.00000000, …
# $ Texture_Entropy_orignal_rescale_3_01_256                 <dbl> 85.00000000, …
# $ Texture_Entropy_orignal_rescale_3_02_256                 <dbl> 86.0000000, 4…
# $ Texture_Entropy_orignal_rescale_3_03_256                 <dbl> 87.00000000, …
# $ Texture_InfoMeas1_orignal_rescale_3_00_256               <dbl> 88.000000000,…
# $ Texture_InfoMeas1_orignal_rescale_3_01_256               <dbl> 89.000000000,…
# $ Texture_InfoMeas1_orignal_rescale_3_02_256               <dbl> 90.000000000,…
# $ Texture_InfoMeas1_orignal_rescale_3_03_256               <dbl> 91.000000000,…
# $ Texture_InfoMeas2_orignal_rescale_3_00_256               <dbl> 92.000000000,…
# $ Texture_InfoMeas2_orignal_rescale_3_01_256               <dbl> 93.000000000,…
# $ Texture_InfoMeas2_orignal_rescale_3_02_256               <dbl> 94.000000000,…
# $ Texture_InfoMeas2_orignal_rescale_3_03_256               <dbl> 95.000000000,…
# $ Texture_InverseDifferenceMoment_orignal_rescale_3_00_256 <dbl> 96.000000000,…
# $ Texture_InverseDifferenceMoment_orignal_rescale_3_01_256 <dbl> 97.00000000, …
# $ Texture_InverseDifferenceMoment_orignal_rescale_3_02_256 <dbl> 98.000000000,…
# $ Texture_InverseDifferenceMoment_orignal_rescale_3_03_256 <dbl> 99.000000000,…
# $ Texture_SumAverage_orignal_rescale_3_00_256              <dbl> 100.00000000,…
# $ Texture_SumAverage_orignal_rescale_3_01_256              <dbl> 101.0000000, …
# $ Texture_SumAverage_orignal_rescale_3_02_256              <dbl> 102.00000000,…
# $ Texture_SumAverage_orignal_rescale_3_03_256              <dbl> 103.0000000, …
# $ Texture_SumEntropy_orignal_rescale_3_00_256              <dbl> 104.00000000,…
# $ Texture_SumEntropy_orignal_rescale_3_01_256              <dbl> 105.00000000,…
# $ Texture_SumEntropy_orignal_rescale_3_02_256              <dbl> 106.00000000,…
# $ Texture_SumEntropy_orignal_rescale_3_03_256              <dbl> 107.00000000,…
# $ Texture_SumVariance_orignal_rescale_3_00_256             <dbl> 108.0000000, …
# $ Texture_SumVariance_orignal_rescale_3_01_256             <dbl> 109.000000, 4…
# $ Texture_SumVariance_orignal_rescale_3_02_256             <dbl> 110.000000, 4…
# $ Texture_SumVariance_orignal_rescale_3_03_256             <dbl> 111.000000, 4…
# $ Texture_Variance_orignal_rescale_3_00_256                <dbl> 1.120000e+02,…
# $ Texture_Variance_orignal_rescale_3_01_256                <dbl> 113.0000000, …
# $ Texture_Variance_orignal_rescale_3_02_256                <dbl> 114.0000000, …
# $ Texture_Variance_orignal_rescale_3_03_256                <dbl> 1.150000e+02,…
# $ uwell                                                    <dbl> 116.0000000, …
# $ Projected_volume_mm3                                     <dbl> 1.170000e+02,…
# $ microwells                                               <dbl> 118, 486, 475…
# $ spheroids                                                <dbl> 119, 486, 486…
# $ inwell_perc                                              <dbl> 120.00000, 48…
# $ outwell_perc                                             <dbl> 121.00000, 48…
# $ Row                                                      <chr> "A", "A", "A"…
# $ Column                                                   <chr> "6", "6", "6"…

# %%
# Save summary data
summary_csv <- paste0("stella/output/images/",image_name,"/",image_name,"_summary_data.csv")
write.csv(df_summary,summary_csv)
